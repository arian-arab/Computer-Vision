# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from keras.datasets import mnist
import cv2
np.random.seed(42)

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = np.array([cv2.resize(i, (32,32)) for i in x_train])
x_test = np.array([cv2.resize(i, (32,32)) for i in x_test])

# %%
def get_binary_mask(image):
    mask = np.copy(image)
    mask[mask>0.1]=1
    mask[mask!=1]=0
    return mask    

def mnist_multiclass(x_train,y_train,number_of_instances): 
    if number_of_instances>64:
        number_of_instances = 64
    idx = np.random.choice(np.arange(len(x_train)), number_of_instances)
    imgs = x_train[idx]
    msks = np.array([get_binary_mask(i) for i in imgs])
    classes = y_train[idx]
    
    x,y = np.meshgrid(np.arange(0,256,32),np.arange(0,256,32))
    possible_choices = []
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            possible_choices.append([x[0,i],y[j,0]])
    possible_choices = np.array(possible_choices)        
    
    choices = np.random.choice(len(possible_choices), number_of_instances, replace = False)
    choices = possible_choices[choices,:]  
    
    msk = np.zeros((256,256,11))
    img = np.zeros((256,256))
    
    msk[:,:,10]=1
    for k in range(number_of_instances):
        x_i = choices[k,0]
        y_i = choices[k,1]
        x_f = x_i + 32
        y_f = y_i + 32
        img[x_i:x_f,y_i:y_f] = imgs[k]
        msk[x_i:x_f,y_i:y_f,classes[k]] = msks[k]
        instance = np.copy(msks[k])
        instance = instance/255
        instance[instance!=0] = -1 
        instance[instance==0]=1
        instance[instance==-1] = 0
        msk[x_i:x_f,y_i:y_f,10] = instance   
    
    gaussian_noise = np.random.normal(0, 127.5, img.shape).astype(np.float32)
    # Add the noise to the image
    noisy_img = img.astype(np.float32) + gaussian_noise
    noisy_img = np.clip(noisy_img, 0, 255).astype(np.uint8)    
    blurred_img = cv2.GaussianBlur(noisy_img, (5, 5), sigmaX=0)
    
    return blurred_img, msk

# %%
number_of_instances = 10
img, msk = mnist_multiclass(x_train,y_train,number_of_instances)

plt.figure()
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(msk[:,:,10], cmap = 'gray', alpha = 0.5)

# %%
############## Create Training/Testing Data ##############
number_of_instances = np.arange(5,20)
train = [mnist_multiclass(x_train,y_train,np.random.choice(number_of_instances)) for i in range(1000)]
train_imgs = np.array([np.expand_dims(i[0], axis = -1)/255.0 for i in train])
train_msks = np.array([i[1]/1.0 for i in train])
del train

test = [mnist_multiclass(x_train,y_train,np.random.choice(number_of_instances)) for i in range(100)]
test_imgs = np.array([np.expand_dims(i[0], axis = -1)/255.0 for i in test])
test_msks = np.array([i[1]/1.0 for i in test])
del test

del x_train, y_train, x_test, y_test,number_of_instances 

plt.figure()
plt.subplot(1,2,1)
plt.imshow(train_imgs[0])
plt.subplot(1,2,2)
plt.imshow(train_msks[0][:,:,10])

# %%
############## Segmentation Model ##############
def build_segmentation_model():
    input_img = layers.Input(shape=(256, 256, 1))  # Input size: 16x16, 3 channels (RGB)

    # Encoder (Downsampling)
    c1 = layers.Conv2D(16, 3, strides=2, padding='same', activation = 'relu')(input_img) #128
    c2 = layers.Conv2D(32, 3, strides=2, padding='same', activation = 'relu')(c1) # 64
    c3 = layers.Conv2D(64, 3, strides=2, padding='same', activation = 'relu')(c2) # 32
    c4 = layers.Conv2D(128, 3, strides=2, padding='same', activation = 'relu')(c3) # 16
    c5 = layers.Conv2D(256, 3, strides=2, padding='same', activation = 'relu')(c4) # 8
    c6 = layers.Conv2D(512, 3, strides=2, padding='same', activation = 'relu')(c5) # 4
    c7 = layers.Conv2D(1024, 3, strides=2, padding='same', activation = 'relu')(c6) # 2
    
    
    # bottleneck
    bottleneck = layers.Conv2D(1024, 3, activation='relu', strides=2, padding='same')(c7)  #1    
   
    # Decoder (Upsampling)
    d1 = layers.Conv2DTranspose(1024, 3, strides=2, padding='same', activation = 'relu')(bottleneck) #2
    d1 = layers.concatenate([d1, c7])

    d2 = layers.Conv2DTranspose(512, 3, strides=2, padding='same', activation = 'relu')(d1) #4
    d2 = layers.concatenate([d2, c6])
    
    d3 = layers.Conv2DTranspose(256, 3, strides=2, padding='same', activation = 'relu')(d2) #8
    d3 = layers.concatenate([d3, c5])
    
    d4 = layers.Conv2DTranspose(128, 3, strides=2, padding='same', activation = 'relu')(d3) #16
    d4 = layers.concatenate([d4, c4])
    
    d5 = layers.Conv2DTranspose(64, 3, strides=2, padding='same', activation = 'relu')(d4) #32
    d5 = layers.concatenate([d5, c3])
    
    d6 = layers.Conv2DTranspose(32, 3, strides=2, padding='same', activation = 'relu')(d5) #64
    d6 = layers.concatenate([d6, c2])
    
    d7 = layers.Conv2DTranspose(16, 3, strides=2, padding='same', activation = 'relu')(d6) #128
    d7 = layers.concatenate([d7, c1])          
    
    # Output layer
    output = layers.Conv2DTranspose(11, (3, 3), activation='softmax', strides=2, padding='same')(d7)     
    model = models.Model(inputs=input_img, outputs=output)
    model.summary()        
    return model

# %%
model = build_segmentation_model()
model.compile(optimizer='adam', loss= 'categorical_crossentropy', metrics = 'accuracy')

history = model.fit(train_imgs, train_msks, batch_size = 32, epochs = 50, validation_split = 0.2)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   4640        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   18496       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 128)  73856       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 256)    295168      conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 4, 512)    1180160     conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 2, 2, 1024)   4719616     conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 1, 1, 1024)   9438208     conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 2, 2, 1024)   9438208     conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 2048)   0           conv2d_transpose[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 4, 4, 512)    9437696     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 8, 8, 256)    2359552     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 512)    0           conv2d_transpose_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 16, 16, 128)  589952      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_3[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 64)   147520      concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 32)   36896       concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_5[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 16) 9232        concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_6[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 11) 3179        concatenate_6[0][0]
# ==================================================================================================
# Total params: 37,752,539
# Trainable params: 37,752,539
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 25/25 [==============================] - 18s 206ms/step - loss: 1.8951 - accuracy: 0.6835 - val_loss: 0.6491 - val_accuracy: 0.9436
# Epoch 2/50
# 25/25 [==============================] - 3s 137ms/step - loss: 0.3886 - accuracy: 0.9523 - val_loss: 0.3173 - val_accuracy: 0.9519
# Epoch 3/50
# 25/25 [==============================] - 3s 135ms/step - loss: 0.2875 - accuracy: 0.9530 - val_loss: 0.2838 - val_accuracy: 0.9519
# Epoch 4/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.2735 - accuracy: 0.9530 - val_loss: 0.2507 - val_accuracy: 0.9519
# Epoch 5/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.2304 - accuracy: 0.9530 - val_loss: 0.1980 - val_accuracy: 0.9519
# Epoch 6/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1778 - accuracy: 0.9530 - val_loss: 0.1733 - val_accuracy: 0.9519
# Epoch 7/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1663 - accuracy: 0.9530 - val_loss: 0.1674 - val_accuracy: 0.9519
# Epoch 8/50
# 25/25 [==============================] - 3s 132ms/step - loss: 0.1609 - accuracy: 0.9530 - val_loss: 0.1623 - val_accuracy: 0.9519
# Epoch 9/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1548 - accuracy: 0.9531 - val_loss: 0.1554 - val_accuracy: 0.9521
# Epoch 10/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1470 - accuracy: 0.9538 - val_loss: 0.1472 - val_accuracy: 0.9533
# Epoch 11/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1410 - accuracy: 0.9550 - val_loss: 0.1436 - val_accuracy: 0.9542
# Epoch 12/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1380 - accuracy: 0.9558 - val_loss: 0.1409 - val_accuracy: 0.9548
# Epoch 13/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.1355 - accuracy: 0.9562 - val_loss: 0.1389 - val_accuracy: 0.9552
# Epoch 14/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1341 - accuracy: 0.9566 - val_loss: 0.1370 - val_accuracy: 0.9556
# Epoch 15/50
# 25/25 [==============================] - 3s 132ms/step - loss: 0.1320 - accuracy: 0.9570 - val_loss: 0.1347 - val_accuracy: 0.9561
# Epoch 16/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.1299 - accuracy: 0.9576 - val_loss: 0.1323 - val_accuracy: 0.9567
# Epoch 17/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.1270 - accuracy: 0.9584 - val_loss: 0.1295 - val_accuracy: 0.9576
# Epoch 18/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1224 - accuracy: 0.9595 - val_loss: 0.1232 - val_accuracy: 0.9592
# Epoch 19/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1154 - accuracy: 0.9608 - val_loss: 0.1143 - val_accuracy: 0.9606
# Epoch 20/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.1087 - accuracy: 0.9621 - val_loss: 0.1099 - val_accuracy: 0.9618
# Epoch 21/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.1039 - accuracy: 0.9634 - val_loss: 0.1058 - val_accuracy: 0.9629
# Epoch 22/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0995 - accuracy: 0.9646 - val_loss: 0.1032 - val_accuracy: 0.9634
# Epoch 23/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0959 - accuracy: 0.9656 - val_loss: 0.0988 - val_accuracy: 0.9650
# Epoch 24/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0919 - accuracy: 0.9667 - val_loss: 0.0951 - val_accuracy: 0.9658
# Epoch 25/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0874 - accuracy: 0.9680 - val_loss: 0.0905 - val_accuracy: 0.9675
# Epoch 26/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0831 - accuracy: 0.9698 - val_loss: 0.0864 - val_accuracy: 0.9691
# Epoch 27/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0791 - accuracy: 0.9715 - val_loss: 0.0832 - val_accuracy: 0.9709
# Epoch 28/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0750 - accuracy: 0.9731 - val_loss: 0.0789 - val_accuracy: 0.9725
# Epoch 29/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0720 - accuracy: 0.9745 - val_loss: 0.0759 - val_accuracy: 0.9741
# Epoch 30/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0673 - accuracy: 0.9763 - val_loss: 0.0745 - val_accuracy: 0.9752
# Epoch 31/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0633 - accuracy: 0.9777 - val_loss: 0.0704 - val_accuracy: 0.9769
# Epoch 32/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0615 - accuracy: 0.9785 - val_loss: 0.0677 - val_accuracy: 0.9779
# Epoch 33/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0570 - accuracy: 0.9803 - val_loss: 0.0670 - val_accuracy: 0.9787
# Epoch 34/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0532 - accuracy: 0.9818 - val_loss: 0.0658 - val_accuracy: 0.9801
# Epoch 35/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0495 - accuracy: 0.9832 - val_loss: 0.0644 - val_accuracy: 0.9808
# Epoch 36/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0463 - accuracy: 0.9843 - val_loss: 0.0640 - val_accuracy: 0.9816
# Epoch 37/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0437 - accuracy: 0.9852 - val_loss: 0.0632 - val_accuracy: 0.9822
# Epoch 38/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0400 - accuracy: 0.9863 - val_loss: 0.0634 - val_accuracy: 0.9827
# Epoch 39/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0380 - accuracy: 0.9869 - val_loss: 0.0643 - val_accuracy: 0.9823
# Epoch 40/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0354 - accuracy: 0.9878 - val_loss: 0.0632 - val_accuracy: 0.9831
# Epoch 41/50
# 25/25 [==============================] - 3s 134ms/step - loss: 0.0326 - accuracy: 0.9886 - val_loss: 0.0644 - val_accuracy: 0.9830
# Epoch 42/50
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0316 - accuracy: 0.9888 - val_loss: 0.0662 - val_accuracy: 0.9829
# Epoch 43/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0298 - accuracy: 0.9893 - val_loss: 0.0665 - val_accuracy: 0.9834
# Epoch 44/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0272 - accuracy: 0.9901 - val_loss: 0.0691 - val_accuracy: 0.9836
# Epoch 45/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0256 - accuracy: 0.9905 - val_loss: 0.0685 - val_accuracy: 0.9839
# Epoch 46/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0242 - accuracy: 0.9909 - val_loss: 0.0699 - val_accuracy: 0.9835
# Epoch 47/50
# 25/25 [==============================] - 3s 128ms/step - loss: 0.0227 - accuracy: 0.9914 - val_loss: 0.0733 - val_accuracy: 0.9836
# Epoch 48/50
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0217 - accuracy: 0.9916 - val_loss: 0.0761 - val_accuracy: 0.9834
# Epoch 49/50
# 25/25 [==============================] - 3s 130ms/step - loss: 0.0210 - accuracy: 0.9918 - val_loss: 0.0746 - val_accuracy: 0.9838
# Epoch 50/50
# 25/25 [==============================] - 3s 124ms/step - loss: 0.0203 - accuracy: 0.9920 - val_loss: 0.0766 - val_accuracy: 0.9837

# %%
plt.figure()
plt.plot(history.history['loss'], c = 'b')
plt.plot(history.history['val_loss'], c = 'r')

# %%
predictions = model.predict(test_imgs)
predictions = np.argmax(predictions, axis = -1)
ground_truth = np.argmax(test_msks, axis = -1)

plt.figure()
plt.subplot(1,2,1)
plt.imshow(ground_truth[10])
plt.subplot(1,2,2)
plt.imshow(predictions[10])

# %%
def calculate_cm(mask,pred,number_of_classes):
    # this function takes in a predicted segmentation mask and an annotated ground truth mask for a k-class segmentation task
    # to calculate confusion matrix, the rows are the ground-turth labels and the columns are the predictions       
    if mask.shape == pred.shape:
        mask = mask.flatten()
        pred = pred.flatten()
        cm = np.zeros((number_of_classes,number_of_classes))
        for i in range(number_of_classes):
            for j in range(number_of_classes):
                cm[i,j] = np.sum(np.logical_and(mask==i, pred==j))
        return cm
    else:
        print('The prediction and the ground truth segmentation masks are of different size')
        return []

def calculate_dice_binary_matrix(cm):  
    if np.sum(cm, axis =1)[0] ==0:
        dice = np.nan  
    else:
        dice = 2*cm[0, 0]/(2*cm[0, 0] + cm[0, 1] + cm[1, 0])  
    return dice

def convert_m_by_m_matrix_to_2_by_2(mat, index = 3):
    mat_copy = np.copy(mat)
    mat_copy[[index,0],:] = mat_copy[[0,index],:]  
    mat_copy[:,[index,0]] = mat_copy[:,[0,index]]  
    two_by_two_matrix = np.zeros((2,2))
    two_by_two_matrix[0,0] = mat_copy[0,0]
    two_by_two_matrix[0,1] = np.sum(mat_copy[0,1:])
    two_by_two_matrix[1,0] = np.sum(mat_copy[1:,0])
    two_by_two_matrix[1,1] = np.sum(mat_copy[1:,1:])    
    return two_by_two_matrix

def calculate_dice(cm, class_index):
    # CM is a numpy array of size (k,k) where k is the number of class labels
    # If the ground truth label does not contain a class label, a DICE of NA is obtained for that class.
    # dice_val is returned for class k
    cm_conv = convert_m_by_m_matrix_to_2_by_2(cm, index = class_index)
    dice_val = calculate_dice_binary_matrix(cm_conv)
    return dice_val

# %%
cm = [calculate_cm(ground_truth[i],predictions[i],number_of_classes=11) for i in range(100)]
for k in range(10):
    dice = [calculate_dice(cm[i], class_index=k) for i in range(100)]
    dice = [i for i in dice if not np.isnan(i)]
    print('Dice Class '+str(k)+' = '+str(np.round(np.mean(dice),2))+' ['+str(np.round(np.percentile(dice,2.5),2))+', '+str(np.round(np.percentile(dice,97.5),2))+'] 95% CI')
# Out:
# Dice Class 0 = 0.84 [0.19, 0.95] 95% CI
# Dice Class 1 = 0.79 [0.33, 0.95] 95% CI
# Dice Class 2 = 0.78 [0.0, 0.94] 95% CI
# Dice Class 3 = 0.72 [0.0, 0.92] 95% CI
# Dice Class 4 = 0.67 [0.0, 0.93] 95% CI
# Dice Class 5 = 0.65 [0.0, 0.92] 95% CI
# Dice Class 6 = 0.79 [0.02, 0.95] 95% CI
# Dice Class 7 = 0.74 [0.0, 0.94] 95% CI
# Dice Class 8 = 0.76 [0.15, 0.95] 95% CI
# Dice Class 9 = 0.67 [0.01, 0.94] 95% CI
